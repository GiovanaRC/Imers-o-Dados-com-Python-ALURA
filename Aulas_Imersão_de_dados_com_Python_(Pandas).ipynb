# %% [markdown]
# <a href="https://colab.research.google.com/github/GiovanaRC/Imers-o-Dados-com-Python-ALURA/blob/main/Aulas_Imers%C3%A3o_de_dados_com_Python_(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 AULA

# %%
import pandas as pd # palavra chave pandas

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("linhas:", linhas)
print ("colunas:", colunas)
# Out:
# linhas: 133349
# colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.rename(columns={
    'work_year': 'ano_trabalho',
    'experience_level': 'nivel_experiencia',
    'employment_type': 'tipo_emprego',
    'job_title': 'cargo',
    'salary': 'salario',
    'moeda_salario': 'moeda',
    'salary_in_usd': 'salario_em_usd',
    'residencia_funcionario': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'localizacao_empresa',
    'company_size': 'tamanho_empresa'
}, inplace=True)

display(df.head())
# Out:
#    ano_trabalho nivel_experiencia tipo_emprego               cargo  salario  \
# 0        2025.0                SE           FT  Solutions Engineer   214000
# 1        2025.0                SE           FT  Solutions Engineer   136000
# 2        2025.0                MI           FT       Data Engineer   158800
# 3        2025.0                MI           FT       Data Engineer   139200
# 4        2025.0                EN           FT       Data Engineer    90000
#
#   salary_currency  salario_em_usd employee_residence  remoto  \
# 0             USD          214000                 US     100
# 1             USD          136000                 US     100
# 2             USD          158800                 AU       0
# 3             USD          139200                 AU       0
# 4             USD           90000                 US       0
#
#   localizacao_empresa tamanho_empresa
# 0                  US               M
# 1                  US               M
# ...

# %%
df.columns
# Out:
# Index(['ano_trabalho', 'nivel_experiencia', 'tipo_emprego', 'cargo', 'salario',
#        'salary_currency', 'salario_em_usd', 'employee_residence', 'remoto',
#        'localizacao_empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["nivel_experiencia"].value_counts()
# Out:
# nivel_experiencia
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["tipo_emprego"].value_counts()
# Out:
# tipo_emprego
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
df['tipo_emprego'] = df['tipo_emprego'].replace({
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
})

display(df['tipo_emprego'].value_counts())
# Out:
# tipo_emprego
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
df['remoto'] = df['remoto'].replace({
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
})

display(df['remoto'].value_counts())
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'] = df['tamanho_empresa'].replace({
    'S': 'Pequena',
    'M': 'Média',
    'L': 'Grande'
})

display(df['tamanho_empresa'].value_counts())
# Out:
# tamanho_empresa
# Média      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    ano_trabalho nivel_experiencia    tipo_emprego               cargo  \
# 0        2025.0                SE  Tempo Integral  Solutions Engineer
# 1        2025.0                SE  Tempo Integral  Solutions Engineer
# 2        2025.0                MI  Tempo Integral       Data Engineer
# 3        2025.0                MI  Tempo Integral       Data Engineer
# 4        2025.0                EN  Tempo Integral       Data Engineer
#
#    salario salary_currency  salario_em_usd employee_residence      remoto  \
# 0   214000             USD          214000                 US      Remoto
# 1   136000             USD          136000                 US      Remoto
# 2   158800             USD          158800                 AU  Presencial
# 3   139200             USD          139200                 AU  Presencial
# 4    90000             USD           90000                 US  Presencial
#
#   localizacao_empresa tamanho_empresa
# 0                  US           Média
# ...

# %%
df.describe(include="object")
# Out:
#        nivel_experiencia    tipo_emprego           cargo salary_currency  \
# count             133349          133349          133349          133349
# unique                 4               4             390              26
# top                   SE  Tempo Integral  Data Scientist             USD
# freq               77241          132563           17314          126140
#
#        employee_residence      remoto localizacao_empresa tamanho_empresa
# count              133349      133349              133349          133349
# unique                102           3                  95               3
# top                    US  Presencial                  US           Média
# freq               119579      105312              119641          129561

# %%
df.describe()
# Out:
#         ano_trabalho       salario  salario_em_usd
# count  133339.000000  1.333490e+05   133349.000000
# mean     2024.358770  1.632833e+05   157617.272098
# std         0.680627  2.173860e+05    74288.363097
# min      2020.000000  1.400000e+04    15000.000000
# 25%      2024.000000  1.060200e+05   106000.000000
# 50%      2024.000000  1.470000e+05   146206.000000
# 75%      2025.000000  1.990000e+05   198000.000000
# max      2025.000000  3.040000e+07   800000.000000

# %% [markdown]
# # 2 AULA

# %%
df.isnull() # palavra chave print
# Out:
#         ano_trabalho  nivel_experiencia  tipo_emprego  cargo  salario  \
# 0              False              False         False  False    False
# 1              False              False         False  False    False
# 2              False              False         False  False    False
# 3              False              False         False  False    False
# 4              False              False         False  False    False
# ...              ...                ...           ...    ...      ...
# 133344         False              False         False  False    False
# 133345         False              False         False  False    False
# 133346         False              False         False  False    False
# 133347         False              False         False  False    False
# 133348         False              False         False  False    False
#
#         salary_currency  salario_em_usd  employee_residence  remoto  \
# ...

# %%
df.head()
# Out:
#    ano_trabalho nivel_experiencia    tipo_emprego               cargo  \
# 0        2025.0                SE  Tempo Integral  Solutions Engineer
# 1        2025.0                SE  Tempo Integral  Solutions Engineer
# 2        2025.0                MI  Tempo Integral       Data Engineer
# 3        2025.0                MI  Tempo Integral       Data Engineer
# 4        2025.0                EN  Tempo Integral       Data Engineer
#
#    salario salary_currency  salario_em_usd employee_residence      remoto  \
# 0   214000             USD          214000                 US      Remoto
# 1   136000             USD          136000                 US      Remoto
# 2   158800             USD          158800                 AU  Presencial
# 3   139200             USD          139200                 AU  Presencial
# 4    90000             USD           90000                 US  Presencial
#
#   localizacao_empresa tamanho_empresa
# 0                  US           Média
# ...

# %%
df.isnull().sum()
# Out:
# ano_trabalho           10
# nivel_experiencia       0
# tipo_emprego            0
# cargo                   0
# salario                 0
# salary_currency         0
# salario_em_usd          0
# employee_residence      0
# remoto                  0
# localizacao_empresa     0
# tamanho_empresa         0
# dtype: int64

# %%
df['ano_trabalho'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano_trabalho nivel_experiencia    tipo_emprego  \
# 5588             NaN                SE  Tempo Integral
# 59692            NaN                MI  Tempo Integral
# 59710            NaN                EN  Tempo Integral
# 59759            NaN                SE  Tempo Integral
# 59789            NaN                SE  Tempo Integral
# 131000           NaN                SE  Tempo Integral
# 131006           NaN                SE  Tempo Integral
# 133054           NaN                EN  Tempo Integral
# 133281           NaN                MI  Tempo Integral
# 133317           NaN                MI  Tempo Integral
#
#                             cargo  salario salary_currency  salario_em_usd  \
# 5588              Product Manager   184500             USD          184500
# 59692                    Engineer   110000             USD          110000
# 59710              Data Scientist   208800             USD          208800
# ...

# %%
import numpy as np

df_salarios = pd.DataFrame ({
    'nome': ["João", "Maria", "José", "Ana", "Pedro"],
    'salario': [1000, np.nan, 3000, np.nan, 5000]
})

df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#     nome  salario  salario_media  salario_mediana
# 0   João   1000.0         1000.0           1000.0
# 1  Maria      NaN         3000.0           3000.0
# 2   José   3000.0         3000.0           3000.0
# 3    Ana      NaN         3000.0           3000.0
# 4  Pedro   5000.0         5000.0           5000.0

# %%
df_temparaturas = pd.DataFrame ({
    'Dia': ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    'Temperatura': [30, np.nan, np.nan, 32,28]
})

df_temparaturas['preenchido_bfill'] = df_temparaturas['Temperatura'].bfill()

df_temparaturas
# Out:
#        Dia  Temperatura  preenchido_bfill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              32.0
# 2   Quarta          NaN              32.0
# 3   Quinta         32.0              32.0
# 4    Sexta         28.0              28.0

# %%
df_cidades = pd.DataFrame({
'nome': ["João", "Maria", "José", "Ana", "Pedro"],
'cidade': ["São Paulo", "np.nan", "Belo Horizonte", "np.nan", "Rio de Janeiro"]
})

df_cidades['cidade_preechida'] = df_cidades['cidade'].fillna('Não informado')
df_cidades
# Out:
#     nome          cidade cidade_preechida
# 0   João       São Paulo        São Paulo
# 1  Maria          np.nan           np.nan
# 2   José  Belo Horizonte   Belo Horizonte
# 3    Ana          np.nan           np.nan
# 4  Pedro  Rio de Janeiro   Rio de Janeiro

# %% [markdown]
# # 3 AULA

# %%
df.head() # palavra chave matplotlib
# Out:
#    ano_trabalho nivel_experiencia    tipo_emprego               cargo  \
# 0        2025.0                SE  Tempo Integral  Solutions Engineer
# 1        2025.0                SE  Tempo Integral  Solutions Engineer
# 2        2025.0                MI  Tempo Integral       Data Engineer
# 3        2025.0                MI  Tempo Integral       Data Engineer
# 4        2025.0                EN  Tempo Integral       Data Engineer
#
#    salario salary_currency  salario_em_usd employee_residence      remoto  \
# 0   214000             USD          214000                 US      Remoto
# 1   136000             USD          136000                 US      Remoto
# 2   158800             USD          158800                 AU  Presencial
# 3   139200             USD          139200                 AU  Presencial
# 4    90000             USD           90000                 US  Presencial
#
#   localizacao_empresa tamanho_empresa
# 0                  US           Média
# ...

# %%
df['nivel_experiencia'].value_counts().plot(kind='bar', title="distribuição de senioridade")
# Out:
# <Axes: title={'center': 'distribuição de senioridade'}, xlabel='nivel_experiencia'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df, x='nivel_experiencia', y='salario')
# Out:
# <Axes: xlabel='nivel_experiencia', ylabel='salario'>

# %% [markdown]
# import matplotlib.pyplot as plt

# %%
df['nivel_experiencia'].value_counts().plot(kind='bar', title="distribuição de senioridade")
# Out:
# <Axes: title={'center': 'distribuição de senioridade'}, xlabel='nivel_experiencia'>

# %%
df.groupby(['nivel_experiencia'])['salario_em_usd'].mean().sort_values(ascending=False)
# Out:
# nivel_experiencia
# EX    202027.667813
# SE    172850.003845
# MI    143041.323489
# EN     99039.040264
# Name: salario_em_usd, dtype: float64

# %%
ordernação =df.groupby(['nivel_experiencia'])['salario_em_usd'].mean().sort_values(ascending=False).index
ordernação
# Out:
# Index(['EX', 'SE', 'MI', 'EN'], dtype='object', name='nivel_experiencia')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='nivel_experiencia', y='salario_em_usd', order=ordernação)
plt.title("Média de salário por nível de experiência")
plt.xlabel("Nível de experiência")
plt.ylabel("Média de salário anual")

plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['salario_em_usd'], bins= 30, kde=True)
plt.title("Destribuição dos salarios anuais")
plt.xlabel("Salarios")
plt.ylabel("Frequência")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['salario_em_usd'])
plt.title("Boxplot salario")
plt.xlabel("Salarios")
plt.show()

# %%
ordernação_nivel_experiencia = ["EN", "MI", "SE", "EX"]

plt.figure(figsize=(8, 5))
sns.boxplot(x = 'nivel_experiencia', y = 'salario_em_usd', data=df, order=ordernação_nivel_experiencia)
plt.title("Distribuição salarial por senioridade")
plt.xlabel("Salarios")
plt.show()

# %%
ordernação_nivel_experiencia = ["EN", "MI", "SE", "EX"]

plt.figure(figsize=(8, 5))
sns.boxplot(x = 'nivel_experiencia', y = 'salario_em_usd', data=df, order=ordernação_nivel_experiencia, palette="Set2", hue="nivel_experiencia")
plt.title("Distribuição salarial por senioridade")
plt.xlabel("Salarios")
plt.show()

# %%
import plotly.express as px

# %%
media_salario_por_nivel = df.groupby('nivel_experiencia')['salario_em_usd'].mean().reset_index()
media_salario_por_nivel = media_salario_por_nivel.sort_values('salario_em_usd', ascending=False)

fig = px.bar(media_salario_por_nivel, x='nivel_experiencia', y='salario_em_usd',
             title='Média de Salário por Nível de Experiência',
             labels={'nivel_experiencia': 'Nível de Experiência', 'salario_em_usd': 'Média de Salário Anual'},
             color='nivel_experiencia') # Optional: Add color based on experience level
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_count = df['remoto'].value_counts().reset_index()
remoto_count.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_count,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção de Tipos de Trabalho Remoto',
             hole=0.5,
             color='tipo_trabalho') # Optional: Add color based on experience level
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_count = df['remoto'].value_counts().reset_index()
remoto_count.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_count,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção de Tipos de Trabalho Remoto',
             hole=0.5,
             color='tipo_trabalho') # Optional: Add color based on experience level

fig.update_traces(textinfo ='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_ds = df[df['cargo'] == 'Data Scientist']

media_salario_ds_localizacao = df_ds.groupby('localizacao_empresa')['salario_em_usd'].mean().reset_index()
media_salario_ds_localizacao = media_salario_ds_localizacao.sort_values('salario_em_usd', ascending=False)

fig = px.bar(media_salario_ds_localizacao, x='localizacao_empresa', y='salario_em_usd',
             title='Média de Salário para Data Scientists por Localização da Empresa',
             labels={'localizacao_empresa': 'Localização da Empresa', 'salario_em_usd': 'Média de Salário Anual em USD'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 4 AULA

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# --- Configuração da Página ---
# Define o título da página, o ícone e o layout para ocupar a largura inteira.
st.set_page_config(
    page_title="Dashboard de Salários na Área de Dados",
    page_icon="📊",
    layout="wide",
)

# --- Carregamento dos dados ---
df = pd.read_csv("https://raw.githubusercontent.com/vqrca/dashboard_salarios_dados/refs/heads/main/dados-imersao-final.csv")

# --- Barra Lateral (Filtros) ---
st.sidebar.header("🔍 Filtros")

# Filtro de Ano
anos_disponiveis = sorted(df['ano'].unique())
anos_selecionados = st.sidebar.multiselect("Ano", anos_disponiveis, default=anos_disponiveis)

# Filtro de Senioridade
senioridades_disponiveis = sorted(df['senioridade'].unique())
senioridades_selecionadas = st.sidebar.multiselect("Senioridade", senioridades_disponiveis, default=senioridades_disponiveis)

# Filtro por Tipo de Contrato
contratos_disponiveis = sorted(df['contrato'].unique())
contratos_selecionados = st.sidebar.multiselect("Tipo de Contrato", contratos_disponiveis, default=contratos_disponiveis)

# Filtro por Tamanho da Empresa
tamanhos_disponiveis = sorted(df['tamanho_empresa'].unique())
tamanhos_selecionados = st.sidebar.multiselect("Tamanho da Empresa", tamanhos_disponiveis, default=tamanhos_disponiveis)

# --- Filtragem do DataFrame ---
# O dataframe principal é filtrado com base nas seleções feitas na barra lateral.
df_filtrado = df[
    (df['ano'].isin(anos_selecionados)) &
    (df['senioridade'].isin(senioridades_selecionadas)) &
    (df['contrato'].isin(contratos_selecionados)) &
    (df['tamanho_empresa'].isin(tamanhos_selecionados))
]

# --- Conteúdo Principal ---
st.title("🎲 Dashboard de Análise de Salários na Área de Dados")
st.markdown("Explore os dados salariais na área de dados nos últimos anos. Utilize os filtros à esquerda para refinar sua análise.")

# --- Métricas Principais (KPIs) ---
st.subheader("Métricas gerais (Salário anual em USD)")

if not df_filtrado.empty:
    salario_medio = df_filtrado['usd'].mean()
    salario_maximo = df_filtrado['usd'].max()
    total_registros = df_filtrado.shape[0]
    cargo_mais_frequente = df_filtrado["cargo"].mode()[0]
else:
    salario_medio, salario_mediano, salario_maximo, total_registros, cargo_mais_comum = 0, 0, 0, ""

col1, col2, col3, col4 = st.columns(4)
col1.metric("Salário médio", f"${salario_medio:,.0f}")
col2.metric("Salário máximo", f"${salario_maximo:,.0f}")
col3.metric("Total de registros", f"{total_registros:,}")
col4.metric("Cargo mais frequente", cargo_mais_frequente)

st.markdown("---")

# --- Análises Visuais com Plotly ---
st.subheader("Gráficos")

col_graf1, col_graf2 = st.columns(2)

with col_graf1:
    if not df_filtrado.empty:
        top_cargos = df_filtrado.groupby('cargo')['usd'].mean().nlargest(10).sort_values(ascending=True).reset_index()
        grafico_cargos = px.bar(
            top_cargos,
            x='usd',
            y='cargo',
            orientation='h',
            title="Top 10 cargos por salário médio",
            labels={'usd': 'Média salarial anual (USD)', 'cargo': ''}
        )
        grafico_cargos.update_layout(title_x=0.1, yaxis={'categoryorder':'total ascending'})
        st.plotly_chart(grafico_cargos, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de cargos.")

with col_graf2:
    if not df_filtrado.empty:
        grafico_hist = px.histogram(
            df_filtrado,
            x='usd',
            nbins=30,
            title="Distribuição de salários anuais",
            labels={'usd': 'Faixa salarial (USD)', 'count': ''}
        )
        grafico_hist.update_layout(title_x=0.1)
        st.plotly_chart(grafico_hist, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de distribuição.")

col_graf3, col_graf4 = st.columns(2)

with col_graf3:
    if not df_filtrado.empty:
        remoto_contagem = df_filtrado['remoto'].value_counts().reset_index()
        remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
        grafico_remoto = px.pie(
            remoto_contagem,
            names='tipo_trabalho',
            values='quantidade',
            title='Proporção dos tipos de trabalho',
            hole=0.5
        )
        grafico_remoto.update_traces(textinfo='percent+label')
        grafico_remoto.update_layout(title_x=0.1)
        st.plotly_chart(grafico_remoto, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico dos tipos de trabalho.")

with col_graf4:
    if not df_filtrado.empty:
        df_ds = df_filtrado[df_filtrado['cargo'] == 'Data Scientist']
        media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
        grafico_paises = px.choropleth(media_ds_pais,
            locations='residencia_iso3',
            color='usd',
            color_continuous_scale='rdylgn',
            title='Salário médio de Cientista de Dados por país',
            labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
        grafico_paises.update_layout(title_x=0.1)
        st.plotly_chart(grafico_paises, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de países.")

# --- Tabela de Dados Detalhados ---
st.subheader("Dados Detalhados")
st.dataframe(df_filtrado)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1360346418.py in <cell line: 0>()
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import plotly.express as px
#       4
#       5 # --- Configuração da Página ---
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
